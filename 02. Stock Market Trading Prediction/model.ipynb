# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import tensorflow as tf
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt 

from tensorflow.keras.layers import Normalization, InputLayer, Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import MeanSquaredError
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.metrics import RootMeanSquaredError

# %% [markdown]
# **Data Loading and Visualization**

# %%
data=pd.read_csv('AMZN.csv')
print(data.shape)
print(data.head())
# Out:
# (5852, 7)
#          Date      Open      High       Low     Close  Adj Close    Volume
# 0  1997-05-15  2.437500  2.500000  1.927083  1.958333   1.958333  72156000
# 1  1997-05-16  1.968750  1.979167  1.708333  1.729167   1.729167  14700000
# 2  1997-05-19  1.760417  1.770833  1.625000  1.708333   1.708333   6106800
# 3  1997-05-20  1.729167  1.750000  1.635417  1.635417   1.635417   5467200
# 4  1997-05-21  1.635417  1.645833  1.375000  1.427083   1.427083  18853200

# %%
data_header=data.columns
print(data_header)
#sns.pairplot(data[data_header],diag_kind="kde")
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %% [markdown]
# **Data Preparation**

# %%
print(data.dtypes)
# Out:
# Date          object
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Adj Close    float64
# Volume         int64
# dtype: object

# %%
'''We need to truncate Date col since it is an object type, following both way is ok'''
#tensor_data=tf.random.shuffle(tf.cast(tf.constant(data[data_header[1:]]),tf.float32)) 
tensor_data=tf.random.shuffle(tf.cast(tf.constant(data.select_dtypes(['float64','int64'])),tf.float32))
print(tensor_data.shape)
#print(tensor_data[:5])
# Out:
# (5852, 6)

# %%
'''feature data= Open High Low Volume'''
x=tf.gather(tensor_data,[0,1,2,5],axis=1)
print(x.shape)
#print(x[:5])
# Out:
# (5852, 4)

# %%
y=tf.gather(tensor_data,[3],axis=1)
print(y.shape)
#print(y[:5])
# Out:
# (5852, 1)

# %%
TRAIN_RATIO=.8
VAL_RATIO=.1
TEST_RATIO=.1
DATASET_SIZE=len(x)

# %%
x_train=x[:int(DATASET_SIZE*TRAIN_RATIO)]
y_train=y[:int(DATASET_SIZE*TRAIN_RATIO)]
print(x_train.shape,y_train.shape)
# Out:
# (4681, 4) (4681, 1)

# %%
x_val=x[int(DATASET_SIZE*TRAIN_RATIO):int(DATASET_SIZE*(TRAIN_RATIO+VAL_RATIO))]
y_val=y[int(DATASET_SIZE*TRAIN_RATIO):int(DATASET_SIZE*(TRAIN_RATIO+VAL_RATIO))]
print(x_val.shape,y_val.shape)
# Out:
# (585, 4) (585, 1)

# %%
x_test=x[int(DATASET_SIZE*(TRAIN_RATIO+VAL_RATIO)):]
y_test=y[int(DATASET_SIZE*(TRAIN_RATIO+VAL_RATIO)):]
print(x_test.shape,y_test.shape)
# Out:
# (586, 4) (586, 1)

# %%
normalizer=Normalization()
normalizer.adapt(x_train)
normalizer(x_train)[:5]
# Out:
# <tf.Tensor: shape=(5, 4), dtype=float32, numpy=
# array([[-0.55125415, -0.55007595, -0.55200213, -0.04429263],
#        [-0.11516892, -0.12105001, -0.12093534, -0.69755596],
#        [-0.4818545 , -0.4830578 , -0.4829098 , -0.20447145],
#        [-0.14950791, -0.1541772 , -0.149561  , -0.7342796 ],
#        [-0.57102513, -0.57088214, -0.5702308 , -0.41144344]],
#       dtype=float32)>

# %% [markdown]
# **Model Preparation**

# %%
model=Sequential([
    InputLayer(shape=(x_train.shape[1],)),
    normalizer,
    Dense(128, activation='relu'),
    Dense(128, activation='relu'),
    Dense(128, activation='relu'),
    Dense(1)
])
model.summary()
# Out:
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ normalization_7 (Normalization) │ (None, 4)              │             9 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_32 (Dense)                │ (None, 128)            │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_33 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_34 (Dense)                │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_35 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 33,802 (132.04 KB)
#  Trainable params: 33,793 (132.00 KB)
#  Non-trainable params: 9 (40.00 B)

# %%
tf.keras.utils.plot_model(model,"model.png",True)

# %%
model.compile(optimizer=Adam(learning_rate=0.3), #updates model's weights and bias to reduce loss
              loss=MeanSquaredError(), #calculates loss/cost of the model
              metrics=[RootMeanSquaredError()]) # Used to evaluate and monitor how well the model is doing — but not used to train the model.

# %% [markdown]
# **Model Training**

# %%
history=model.fit(x_train,y_train,validation_data=(x_val,y_val), epochs=50,verbose=1)
# Out:
# Epoch 1/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 491383.5938 - root_mean_squared_error: 640.4506 - val_loss: 2073.1995 - val_root_mean_squared_error: 45.5324
# Epoch 2/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 3450.2544 - root_mean_squared_error: 58.3538 - val_loss: 4998.8286 - val_root_mean_squared_error: 70.7024
# Epoch 3/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2198.5676 - root_mean_squared_error: 46.7251 - val_loss: 1009.4233 - val_root_mean_squared_error: 31.7714
# Epoch 4/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1152.4451 - root_mean_squared_error: 33.8941 - val_loss: 1907.1641 - val_root_mean_squared_error: 43.6711
# Epoch 5/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2491.6128 - root_mean_squared_error: 48.2706 - val_loss: 3090.7183 - val_root_mean_squared_error: 55.5942
# Epoch 6/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1209.9146 - root_mean_squared_error: 34.4477 - val_loss: 495.8635 - val_root_mean_squared_error: 22.2680
# Epoch 7/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 803.2962 - root_mean_squared_error: 28.2607 - val_loss: 2319.9502 - val_root_mean_squared_error: 48.1659
# Epoch 8/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 4129.0718 - root_mean_squared_error: 63.7382 - val_loss: 681.2403 - val_root_mean_squared_error: 26.1006
# Epoch 9/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1036.1914 - root_mean_squared_error: 32.1021 - val_loss: 537.2235 - val_root_mean_squared_error: 23.1781
# Epoch 10/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 16818.7480 - root_mean_squared_error: 126.0794 - val_loss: 1164.2328 - val_root_mean_squared_error: 34.1209
# Epoch 11/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1444.7306 - root_mean_squared_error: 37.6957 - val_loss: 392.6681 - val_root_mean_squared_error: 19.8159
# Epoch 12/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 748.4670 - root_mean_squared_error: 27.1515 - val_loss: 495.7782 - val_root_mean_squared_error: 22.2661
# Epoch 13/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 515.7079 - root_mean_squared_error: 22.6176 - val_loss: 462.1985 - val_root_mean_squared_error: 21.4988
# Epoch 14/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 420.0609 - root_mean_squared_error: 20.4619 - val_loss: 351.4254 - val_root_mean_squared_error: 18.7463
# Epoch 15/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 301.1361 - root_mean_squared_error: 17.3146 - val_loss: 150.6511 - val_root_mean_squared_error: 12.2740
# Epoch 16/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 367.3042 - root_mean_squared_error: 19.0319 - val_loss: 287.8194 - val_root_mean_squared_error: 16.9652
# Epoch 17/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 562.0081 - root_mean_squared_error: 22.1703 - val_loss: 641.7289 - val_root_mean_squared_error: 25.3324
# Epoch 18/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1803.6318 - root_mean_squared_error: 42.3031 - val_loss: 139.2467 - val_root_mean_squared_error: 11.8003
# Epoch 19/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1110.4186 - root_mean_squared_error: 33.1012 - val_loss: 174.8792 - val_root_mean_squared_error: 13.2242
# Epoch 20/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 520.0956 - root_mean_squared_error: 22.6032 - val_loss: 111.1850 - val_root_mean_squared_error: 10.5444
# Epoch 21/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 535.3369 - root_mean_squared_error: 22.9557 - val_loss: 158.5870 - val_root_mean_squared_error: 12.5931
# Epoch 22/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1062.3508 - root_mean_squared_error: 28.2250 - val_loss: 536.3239 - val_root_mean_squared_error: 23.1587
# Epoch 23/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1850.8749 - root_mean_squared_error: 41.8124 - val_loss: 62.1185 - val_root_mean_squared_error: 7.8815
# Epoch 24/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 245.3146 - root_mean_squared_error: 15.2032 - val_loss: 1806.3853 - val_root_mean_squared_error: 42.5016
# Epoch 25/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 611.1100 - root_mean_squared_error: 24.1032 - val_loss: 1408.2052 - val_root_mean_squared_error: 37.5261
# Epoch 26/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1599.3221 - root_mean_squared_error: 35.2600 - val_loss: 43495.6875 - val_root_mean_squared_error: 208.5562
# Epoch 27/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 20706.2168 - root_mean_squared_error: 138.0809 - val_loss: 3067.5300 - val_root_mean_squared_error: 55.3853
# Epoch 28/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2688.8264 - root_mean_squared_error: 51.7633 - val_loss: 2163.9019 - val_root_mean_squared_error: 46.5178
# Epoch 29/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1973.8876 - root_mean_squared_error: 44.4066 - val_loss: 2059.7739 - val_root_mean_squared_error: 45.3847
# Epoch 30/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1484.4816 - root_mean_squared_error: 38.4839 - val_loss: 1465.1208 - val_root_mean_squared_error: 38.2769
# Epoch 31/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1105.0156 - root_mean_squared_error: 33.1829 - val_loss: 1236.2278 - val_root_mean_squared_error: 35.1600
# Epoch 32/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1144.3766 - root_mean_squared_error: 33.7959 - val_loss: 1032.6375 - val_root_mean_squared_error: 32.1347
# Epoch 33/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1092.0073 - root_mean_squared_error: 32.9878 - val_loss: 756.3016 - val_root_mean_squared_error: 27.5009
# Epoch 34/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 956.0218 - root_mean_squared_error: 30.8723 - val_loss: 2605.4619 - val_root_mean_squared_error: 51.0437
# Epoch 35/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1277.9956 - root_mean_squared_error: 35.6199 - val_loss: 896.8505 - val_root_mean_squared_error: 29.9475
# Epoch 36/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1725.1945 - root_mean_squared_error: 41.2299 - val_loss: 442.8724 - val_root_mean_squared_error: 21.0445
# Epoch 37/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 734.9265 - root_mean_squared_error: 26.9965 - val_loss: 730.4441 - val_root_mean_squared_error: 27.0267
# Epoch 38/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 721.6170 - root_mean_squared_error: 26.6217 - val_loss: 516.1650 - val_root_mean_squared_error: 22.7193
# Epoch 39/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1224.5256 - root_mean_squared_error: 33.6946 - val_loss: 472.4603 - val_root_mean_squared_error: 21.7362
# Epoch 40/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1791.2334 - root_mean_squared_error: 41.3941 - val_loss: 196.8893 - val_root_mean_squared_error: 14.0317
# Epoch 41/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 576.2079 - root_mean_squared_error: 23.5293 - val_loss: 190.8411 - val_root_mean_squared_error: 13.8145
# Epoch 42/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 760.0603 - root_mean_squared_error: 26.7407 - val_loss: 523.3081 - val_root_mean_squared_error: 22.8759
# Epoch 43/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1011.0668 - root_mean_squared_error: 31.2626 - val_loss: 415.2334 - val_root_mean_squared_error: 20.3773
# Epoch 44/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 431.0308 - root_mean_squared_error: 20.6995 - val_loss: 510.7142 - val_root_mean_squared_error: 22.5990
# Epoch 45/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2268.5977 - root_mean_squared_error: 44.6712 - val_loss: 218.2878 - val_root_mean_squared_error: 14.7746
# Epoch 46/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 317.1685 - root_mean_squared_error: 17.7232 - val_loss: 321.6244 - val_root_mean_squared_error: 17.9339
# Epoch 47/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 430.0513 - root_mean_squared_error: 20.6241 - val_loss: 1556.5002 - val_root_mean_squared_error: 39.4525
# Epoch 48/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 2730.3594 - root_mean_squared_error: 38.6212 - val_loss: 19264.8828 - val_root_mean_squared_error: 138.7980
# Epoch 49/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 7632.9658 - root_mean_squared_error: 84.7151 - val_loss: 2098.5657 - val_root_mean_squared_error: 45.8101
# Epoch 50/50
# 147/147 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 1468.4381 - root_mean_squared_error: 38.2872 - val_loss: 1228.2808 - val_root_mean_squared_error: 35.0468

# %%
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("Model Loss")
plt.xlabel("epochs")
plt.ylabel("loss")
plt.legend